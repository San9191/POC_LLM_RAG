# %%
from dotenv import load_dotenv
import os
import scraper
from IPython.display import Markdown, display
from openai import OpenAI
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPENAI_API_KEY")
openai = OpenAI()
# Out:
# ChatCompletion(id='chatcmpl-DLMtLJHCevCoQXWMGHaDgs33JRif6', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Hello! Today's date is October 5, 2023. How can I assist you today?", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1773985255, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_5eb02aec96', usage=CompletionUsage(completion_tokens=20, prompt_tokens=15, total_tokens=35, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
message = "Hello, GPT!, what's today's date?"
messages = [{"role": "user", "content": message}]
messages
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
response.choices[0].message.content
# Out:
# "Hello! Today's date is October 16, 2023. How can I assist you today?"

# %%
messages = [{"role": "system", "content": "You are a news anchor"}, {"role": "user", "content": "what first word you say on live TV"}]
response = openai.chat.completions.create(model="gpt-4.1-nano", messages=messages)
response.choices[0].message.content
# Out:
# 'Good evening, everyone.'

# %%
system_prompt = """
You are an assistant that analyzed the contents of a website, and provide a short summary"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
provide a short summary of this website.
"""

# %%
def messages_for(website):
  return[
    {"role": "sytem", "content": system_prompt}, 
    {"role": "user", "content": user_prompt_prefix}
  ]

# %%
def website_fetching(website):
  pass

# %%
def website_summarizer(url):
  website = website_fetching(url)
  response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages_for(website))
  response.choices[0].message.content
