# %% [markdown]
# #### MODELS COMPARISON AND LEADERBOARD USE FOR SELECTION OF BEST MODELS
# This section needs revisit to get the essential techniques and tools used in model selection, NOTE: things might be different by now as the course is from late 2024 and the models, techniques ... etc for model selection might be different/deprecated.
