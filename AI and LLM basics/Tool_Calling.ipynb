# %% [markdown]
# ## Week 2 - Day 4:
#
# This section goes into Tool Calling, instructor would advise in the 4th video of day 4 that most of the intrect code in this section is abstraced with frameworks like OpenAI agent SDK, MS Agent Framework ... etc.

# %%
from openai import OpenAI
from dotenv import load_dotenv
import gradio as gr
import json
from IPython.display import Markdown, display

load_dotenv()
openai = OpenAI()

# %%
ticket_prices = {"london": "$799", "paris": "$899", "tokyo": "$1400", "berlin": "$499"}

def get_ticket_price(destination_city):
    print(f"Tool called for city {destination_city}")
    price = ticket_prices.get(destination_city.lower(), "Unknown ticket price")
    return f"The price of a ticket to {destination_city} is {price}"

# %%
get_ticket_price("")
# Out:
# Tool called for city when
# 'The price of a ticket to when is Unknown ticket price'
